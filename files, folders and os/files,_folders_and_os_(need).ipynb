# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders and OS (Need)</span></div>

# %% [markdown]
# ## Important concepts

# %% [markdown]
# ### Path

# %% [markdown]
# A Path is a way to specify a location on your computer.
#
# You can specify your path *absolutely* or *relatively* (absolutely = actual location, relatively = location relative to another directed locale)
#
# **apparently easier to use relative paths

# %% [markdown]
# ### More about relative paths

# %% [markdown]
# Mac OS X allows us to use ~ to refer to the home directory

# %% [markdown]
# ### Path separator

# %% [markdown]
# Mac OS X uses / as a path separator
#
# e.g., /Users/(name)/Desktop/(file name)

# %% [markdown]
# ### Text files vs Binary files

# %% [markdown]
# Text files can be examined by almost any software (.txt, .md. or .csv)
#
# Binary files require processing to make sense of what they contain. (.png, Excel.exe cannot run on Mac OS X). Binary files are used in favour of Text files because of speed and size.

# %% [markdown]
# ### Extentions

# %% [markdown]
# separated by a full-stop (.), this extension lets the OS know what software or app to extract the details in the file. (.xlsx means Excel or .pptx means PowerPoint)

# %% [markdown]
# ### Opening and closing files

# %%
with open('spectrum-01.txt', 'r') as file:
    file_content = file.read()

print(file_content) #?
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/y3/jh2xk8816tj_l6xs6gt2q4k40000gn/T/ipykernel_1191/1870761100.py in <module>
# ----> 1 with open('spectrum-01.txt', 'r') as file:
#       2     file_content = file.read()
#       3
#       4 print(file_content) #?
#
# FileNotFoundError: [Errno 2] No such file or directory: 'spectrum-01.txt'

# %% [markdown]
# Open() function opens a 'stream' into your file and the 'r' specifies that you only want to read from the file.

# %%
text = 'Far out in the uncharted backwaters of the unfashionable end of the western spiral arm of the Galaxy lies a small unregarded yellow sun.\nOrbiting this at a distance of roughly ninety-two million miles is an utterly insignificant little blue green planet whose ape-descended life forms are so amazingly primitive that they still think digital watches are a pretty neat idea.'

with open('my-text-once.txt', 'w') as file:
    file.write(text)
    
with open('my-text-lines.txt', 'w') as file:
    for line in text.splitlines():
        file.writelines(line)

# %% [markdown]
# ## Playing with the OS

# %% [markdown]
# ### Some packages

# %% [markdown]
# OS is used to 'talk' to the OS to create, modify, delete folders and write OS-agnostic code.
#
# glob is

# %%
import os
import glob
import shutil

# %% [markdown]
# ### OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)

path = os.path.join('.','Documents','Github','learning-portfolio-KeeganLeeNg')
print(path)
# Out:
# ./all-data/sg-data/data-01.txt
# ./Documents/Github/learning-portfolio-KeeganLeeNg

# %% [markdown]
# ### Creating folders

# %%
os.mkdir('people')

for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}') #print is not necessary 
    os.mkdir(path)
# Out:
# Creating people/Jonh
# Creating people/Paul
# Creating people/Ringo

# %% [markdown]
# ### Checking for existence

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people/Jonh already exists; skipping creation.
# people/Paul already exists; skipping creation.
# people/Ringo already exists; skipping creation.

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people/Jonh already exists; skipping creation.
# people/Paul already exists; skipping creation.
# people/Ringo already exists; skipping creation.

# %% [markdown]
# ### Copying files

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('sp2273_logo.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people/Jonh
# Copied file to people/Paul
# Copied file to people/Ringo

# %%
for person in ['Jonh', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'sp2273_logo.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'sp2273_logo.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people/Jonh/imgs/sp2273_logo.png
# Moved logo to people/Paul/imgs/sp2273_logo.png
# Moved logo to people/Ringo/imgs/sp2273_logo.png

# %% [markdown]
# ### Listing files

# %%
glob.glob('*') # asterisk is a wilcard and is read as 'anything'
# Out:
# ['my-text-once.txt',
#  'sp2273_logo.png',
#  'people',
#  'my-text-lines.txt',
#  'files,_folders_and_os_(need).ipynb']

# %%
glob.glob('peo*')
# Out:
# ['people']

# %%
glob.glob('peo*/*')
# Out:
# ['people/Paul', 'people/Jonh', 'people/Ringo']

# %%
glob.glob('people/**', recursive=True)
# Out:
# ['people/',
#  'people/Paul',
#  'people/Paul/imgs',
#  'people/Paul/imgs/sp2273_logo.png',
#  'people/Jonh',
#  'people/Jonh/imgs',
#  'people/Jonh/imgs/sp2273_logo.png',
#  'people/Ringo',
#  'people/Ringo/imgs',
#  'people/Ringo/imgs/sp2273_logo.png']

# %%
glob.glob('people/**/*.png', recursive=True) #specifying
# Out:
# ['people/Paul/imgs/sp2273_logo.png',
#  'people/Jonh/imgs/sp2273_logo.png',
#  'people/Ringo/imgs/sp2273_logo.png']

# %% [markdown]
# ### Moving about

# %%
os.getcwd() #cwd stands for 'current working directory'
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os'

# %%
os.chdir('people/Ringo')

# %% [markdown]
# ### Extracting Info

# %%
path = 'people/Ringo/imgs/sp2273_logo.png' #split the path where the separator occured and picked the last element in the list 
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename, extension)
# Out:
# sp2273_logo.png png

# %%
path = 'people/Ringo/imgs/sp2273_logo.png'
print(os.path.split(path))      # Split filename from the rest
print(os.path.splitext(path))   # Split extension
print(os.path.dirname(path))    # Show the directoryprint(
# Out:
# ('people/Ringo/imgs', 'sp2273_logo.png')
# ('people/Ringo/imgs/sp2273_logo', '.png')
# people/Ringo/imgs

# %% [markdown]
# ### Deleting stuff

# %%
os.remove('people/Ringo/imgs/sp2273_logo.png') #????
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/y3/jh2xk8816tj_l6xs6gt2q4k40000gn/T/ipykernel_1191/1342650435.py in <module>
# ----> 1 os.remove('people/Ringo/imgs/sp2273_logo.png') #????
#
# FileNotFoundError: [Errno 2] No such file or directory: 'people/Ringo/imgs/sp2273_logo.png'

# %%
os.rmdir('people/Ringo') #????
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/y3/jh2xk8816tj_l6xs6gt2q4k40000gn/T/ipykernel_1191/54532714.py in <module>
# ----> 1 os.rmdir('people/Ringo')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'people/Ringo'

# %%
shutil.rmtree('people/Ringo') #????
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/y3/jh2xk8816tj_l6xs6gt2q4k40000gn/T/ipykernel_1191/247889838.py in <module>
# ----> 1 shutil.rmtree('people/Ringo')
#
# ~/opt/anaconda3/lib/python3.9/shutil.py in rmtree(path, ignore_errors, onerror)
#     722             orig_st = os.lstat(path)
#     723         except Exception:
# --> 724             onerror(os.lstat, path, sys.exc_info())
#     725             return
#     726         try:
#
# ~/opt/anaconda3/lib/python3.9/shutil.py in rmtree(path, ignore_errors, onerror)
#     720         # lstat()/open()/fstat() trick.
#     721         try:
# --> 722             orig_st = os.lstat(path)
#     723         except Exception:
#     724             onerror(os.lstat, path, sys.exc_info())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'people/Ringo'

# %% [markdown]
# ## Exercise 7 :  The OS is my oyster

# %%
os.getcwd()
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo'

# %%
os.mkdir('python_today')
os.chdir('python_today') 
print(os.getcwd())
# Out:
# /Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today

# %%
x = range(1,51)

for i in x:
    os.mkdir(f'new_directory_{i}')

# %%
os.getcwd()
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today'

# %%
for i in range (1,51):
    if (i%2)>0:
        os.rmdir(f'new_directory_{i}')

# %%
os.listdir()
# Out:
# ['new_directory_44',
#  'new_directory_10',
#  'new_directory_28',
#  'new_directory_26',
#  'new_directory_42',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_6',
#  'new_directory_16',
#  'new_directory_8',
#  'new_directory_34',
#  'new_directory_32',
#  'new_directory_50',
#  'new_directory_14',
#  'new_directory_4',
#  'new_directory_22',
#  'new_directory_40',
#  'new_directory_2',
#  'new_directory_24',
#  'new_directory_12',
#  'new_directory_46',
#  'new_directory_48',
#  '.ipynb_checkpoints',
#  'new_directory_{i}',
#  'new_directory_30',
#  'new_directory_38',
#  'new_directory_36']

# %%
import os
import glob
import shutil
os.getcwd()
os.chdir('people/Ringo/python_today/python_today')

# %%
os.listdir()
# Out:
# ['new_directory_44',
#  'new_directory_10',
#  'new_directory_28',
#  'new_directory_26',
#  'new_directory_42',
#  'new_directory_18',
#  'new_directory_20',
#  'new_directory_6',
#  'new_directory_16',
#  'new_directory_8',
#  'new_directory_34',
#  'new_directory_32',
#  'new_directory_50',
#  'new_directory_14',
#  'new_directory_4',
#  'new_directory_22',
#  'new_directory_40',
#  'new_directory_2',
#  'new_directory_24',
#  'new_directory_12',
#  'new_directory_46',
#  'new_directory_48',
#  '.ipynb_checkpoints',
#  'new_directory_{i}',
#  'new_directory_30',
#  'new_directory_38',
#  'new_directory_36']

# %%
for i in range(1,51):
    if i%5==0: 
        try:
            os.rename(f'new_directory_{i}',f'haha_{i}')
        except:
            print('python is not stupid because it notifies the programmer of complications')
# Out:
# python is stupid
# python is stupid
# python is stupid
# python is stupid
# python is stupid

# %%
# Out:
# ['new_directory_44',
#  'new_directory_28',
#  'haha_10',
#  'new_directory_26',
#  'new_directory_42',
#  'new_directory_18',
#  'new_directory_6',
#  'new_directory_16',
#  'haha_20',
#  'new_directory_8',
#  'new_directory_34',
#  'new_directory_32',
#  'haha_50',
#  'new_directory_14',
#  'new_directory_4',
#  'new_directory_22',
#  'haha_40',
#  'new_directory_2',
#  'new_directory_24',
#  'new_directory_12',
#  'new_directory_46',
#  'new_directory_48',
#  '.ipynb_checkpoints',
#  'new_directory_{i}',
#  'haha_30',
#  'new_directory_38',
#  'new_directory_36']

# %%
src = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/sp2273_logo.png'
dst = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_10'
shutil.copy(src,dst)
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_10/sp2273_logo.png'

# %%
src = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/sp2273_logo.png'
dst = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_20'
shutil.copy(src,dst)
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_20/sp2273_logo.png'

# %%
src = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/sp2273_logo.png'
dst = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_30'
shutil.copy(src,dst)

src = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/sp2273_logo.png'
dst = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_40'
shutil.copy(src,dst)

src = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/sp2273_logo.png'
dst = '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_50'
shutil.copy(src,dst)
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/people/Ringo/python_today/python_today/haha_50/sp2273_logo.png'

# %%
os.listdir()
# Out:
# ['new_directory_44',
#  'new_directory_28',
#  'haha_10',
#  'new_directory_26',
#  'new_directory_42',
#  'new_directory_18',
#  'new_directory_6',
#  'new_directory_16',
#  'haha_20',
#  'new_directory_8',
#  'new_directory_34',
#  'new_directory_32',
#  'haha_50',
#  'new_directory_14',
#  'new_directory_4',
#  'new_directory_22',
#  'haha_40',
#  'new_directory_2',
#  'new_directory_24',
#  'new_directory_12',
#  'new_directory_46',
#  'new_directory_48',
#  '.ipynb_checkpoints',
#  'new_directory_{i}',
#  'haha_30',
#  'new_directory_38',
#  'new_directory_36']

# %% [markdown]
# ## Exercise 8 :  Tidying a collaboration

# %%
import os
import glob
import shutil
os.chdir('/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/os-collaboration-exercise-data') 
os.getcwd()
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/os-collaboration-exercise-data'

# %%
import os
import glob
import shutil
os.chdir('/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/os-collaboration-exercise-data') 
os.getcwd()
os.listdir()
# Out:
# ['dec-10_osaka.txt',
#  'jul-14_karachi.txt',
#  'nov-17_osaka.txt',
#  'jul-13_cairo.txt',
#  'jun-15_manila.txt',
#  'aug-20_tokyo.txt',
#  'jun-16_melbourne.txt',
#  'sep-05_tokyo.txt',
#  'jun-22_manila.txt',
#  'apr-11_shanghai.txt',
#  'sep-21_singapore.txt',
#  'feb-01_singapore.txt',
#  'may-09_manila.txt',
#  'jan-20_tokyo.txt',
#  'jan-30_manila.txt',
#  'jun-28_tokyo.txt',
#  'apr-16_shanghai.txt',
#  'dec-07_shanghai.txt',
#  'nov-03_singapore.txt',
#  'oct-07_dhaka.txt',
#  'aug-08_osaka.txt',
#  'apr-27_melbourne.txt',
#  'aug-29_karachi.txt',
#  'feb-12_dhaka.txt',
#  'oct-30_manila.txt',
#  'aug-27_dhaka.txt',
#  'jan-19_melbourne.txt',
#  'feb-13_shanghai.txt',
#  'jul-20_melbourne.txt',
#  'sep-11_tokyo.txt',
#  'aug-07_jakarta.txt',
#  'jan-08_osaka.txt',
#  'jun-25_jakarta.txt',
#  'sep-27_jakarta.txt',
#  'may-28_dhaka.txt',
#  'jul-14_jakarta.txt',
#  'oct-14_tokyo.txt',
#  'dec-04_osaka.txt',
#  'may-20_karachi.txt',
#  'aug-08_singapore.txt',
#  'nov-07_singapore.txt',
#  'jan-24_melbourne.txt',
#  'feb-05_singapore.txt',
#  'dec-10_karachi.txt',
#  'dec-19_tokyo.txt',
#  'oct-22_singapore.txt',
#  'sep-25_singapore.txt',
#  'aug-06_dhaka.txt',
#  'apr-04_shanghai.txt',
#  'dec-15_shanghai.txt',
#  'dec-27_cairo.txt',
#  'feb-12_singapore.txt',
#  'apr-02_karachi.txt',
#  'sep-11_manila.txt',
#  'jul-26_cairo.txt',
#  'apr-17_tokyo.txt',
#  'feb-20_tokyo.txt',
#  'dec-25_osaka.txt',
#  'oct-27_shanghai.txt',
#  'apr-03_tokyo.txt',
#  'may-30_cairo.txt',
#  'may-03_melbourne.txt',
#  'oct-17_jakarta.txt',
#  'sep-15_jakarta.txt',
#  'apr-02_jakarta.txt',
#  'mar-16_tokyo.txt',
#  'mar-26_manila.txt',
#  'feb-04_jakarta.txt',
#  'jul-08_karachi.txt',
#  'aug-29_manila.txt',
#  'feb-05_manila.txt',
#  'feb-01_shanghai.txt',
#  'jan-13_cairo.txt',
#  'jul-02_singapore.txt',
#  'jun-19_osaka.txt',
#  'jan-26_jakarta.txt',
#  'aug-20_jakarta.txt',
#  'feb-23_manila.txt',
#  'dec-02_melbourne.txt',
#  'nov-28_karachi.txt',
#  'oct-11_shanghai.txt',
#  'nov-18_melbourne.txt',
#  'apr-12_singapore.txt',
#  'feb-26_cairo.txt',
#  'apr-05_singapore.txt',
#  'jul-20_tokyo.txt',
#  'jun-25_tokyo.txt',
#  'dec-24_shanghai.txt',
#  'oct-16_shanghai.txt',
#  'feb-24_osaka.txt',
#  'dec-15_melbourne.txt',
#  'mar-07_melbourne.txt',
#  'jun-23_singapore.txt',
#  'aug-07_cairo.txt',
#  'sep-22_cairo.txt',
#  'may-04_manila.txt',
#  'apr-07_osaka.txt',
#  'sep-20_osaka.txt',
#  'mar-12_osaka.txt',
#  'nov-21_melbourne.txt',
#  'dec-09_osaka.txt',
#  'oct-19_tokyo.txt',
#  'jun-22_dhaka.txt',
#  'nov-09_manila.txt',
#  'may-03_shanghai.txt',
#  'jan-05_osaka.txt',
#  'aug-20_karachi.txt',
#  'jan-15_singapore.txt',
#  'jun-18_manila.txt',
#  'jan-07_cairo.txt',
#  'sep-14_melbourne.txt',
#  'jan-26_karachi.txt',
#  'nov-13_tokyo.txt',
#  'jun-09_singapore.txt',
#  'feb-11_osaka.txt',
#  'oct-03_shanghai.txt',
#  'aug-26_cairo.txt',
#  'aug-13_manila.txt',
#  'aug-04_melbourne.txt',
#  'apr-24_cairo.txt',
#  'may-07_jakarta.txt',
#  'jul-15_tokyo.txt',
#  'aug-24_manila.txt',
#  'apr-01_singapore.txt',
#  'feb-08_manila.txt',
#  'sep-01_osaka.txt',
#  'may-17_tokyo.txt',
#  'aug-24_osaka.txt',
#  'apr-14_manila.txt',
#  'may-04_dhaka.txt',
#  'jul-06_dhaka.txt',
#  'dec-28_osaka.txt',
#  'oct-21_manila.txt',
#  'oct-04_shanghai.txt',
#  'aug-12_jakarta.txt',
#  'aug-13_melbourne.txt',
#  'may-29_cairo.txt',
#  'sep-09_shanghai.txt',
#  'apr-27_shanghai.txt',
#  'may-29_karachi.txt',
#  'jul-06_singapore.txt',
#  'nov-14_dhaka.txt',
#  'may-29_jakarta.txt',
#  'jul-01_karachi.txt',
#  'jul-28_singapore.txt',
#  'aug-12_karachi.txt',
#  'jul-12_dhaka.txt',
#  'jan-14_karachi.txt',
#  'may-10_dhaka.txt',
#  'jun-17_dhaka.txt',
#  'sep-15_osaka.txt',
#  'may-03_tokyo.txt',
#  'mar-27_osaka.txt',
#  'nov-25_melbourne.txt',
#  'jul-08_shanghai.txt',
#  'nov-15_manila.txt',
#  'dec-21_cairo.txt',
#  'jul-16_singapore.txt',
#  'mar-04_tokyo.txt',
#  'oct-26_shanghai.txt',
#  'sep-05_manila.txt',
#  'dec-23_osaka.txt',
#  'apr-05_shanghai.txt',
#  'nov-24_osaka.txt',
#  'aug-03_melbourne.txt',
#  'apr-12_karachi.txt',
#  'apr-11_tokyo.txt',
#  'oct-21_shanghai.txt',
#  'may-30_karachi.txt',
#  'nov-18_tokyo.txt',
#  'sep-25_dhaka.txt',
#  'apr-02_shanghai.txt',
#  'jul-18_jakarta.txt',
#  'sep-08_cairo.txt',
#  'oct-29_jakarta.txt',
#  'feb-14_jakarta.txt',
#  'jun-29_karachi.txt',
#  'jan-29_shanghai.txt',
#  'aug-14_dhaka.txt',
#  'feb-26_manila.txt',
#  'may-08_tokyo.txt',
#  'may-08_singapore.txt',
#  '.DS_Store',
#  'sep-05_jakarta.txt',
#  'oct-07_jakarta.txt',
#  'nov-22_melbourne.txt',
#  'mar-04_jakarta.txt',
#  'dec-18_dhaka.txt',
#  'jan-23_jakarta.txt',
#  'sep-22_tokyo.txt',
#  'aug-18_cairo.txt',
#  'jul-05_singapore.txt',
#  'apr-18_osaka.txt',
#  'mar-18_jakarta.txt',
#  'dec-06_shanghai.txt',
#  'apr-17_shanghai.txt',
#  'aug-10_melbourne.txt',
#  'jan-24_manila.txt',
#  'sep-19_jakarta.txt',
#  'apr-15_singapore.txt',
#  'aug-17_karachi.txt',
#  'may-17_cairo.txt',
#  'jul-15_cairo.txt',
#  'feb-13_tokyo.txt',
#  'nov-10_manila.txt',
#  'apr-24_tokyo.txt',
#  'oct-06_tokyo.txt',
#  'apr-10_shanghai.txt',
#  'nov-08_melbourne.txt',
#  'jun-12_osaka.txt',
#  'jul-04_karachi.txt',
#  'apr-20_karachi.txt',
#  'apr-20_jakarta.txt',
#  'feb-08_karachi.txt',
#  'aug-21_manila.txt',
#  'aug-16_manila.txt',
#  'sep-17_tokyo.txt',
#  'jun-06_osaka.txt',
#  'jul-04_jakarta.txt',
#  'feb-12_shanghai.txt',
#  'dec-02_osaka.txt',
#  'aug-17_jakarta.txt',
#  'feb-07_tokyo.txt',
#  'nov-26_melbourne.txt',
#  'feb-26_jakarta.txt',
#  'feb-14_dhaka.txt',
#  'apr-23_dhaka.txt',
#  'may-26_shanghai.txt',
#  'oct-01_dhaka.txt',
#  'mar-19_osaka.txt',
#  'may-02_jakarta.txt',
#  'feb-15_shanghai.txt',
#  'jul-07_manila.txt',
#  'sep-13_melbourne.txt',
#  'oct-13_manila.txt',
#  'jul-21_manila.txt',
#  'jan-22_osaka.txt',
#  'sep-08_shanghai.txt',
#  'oct-02_manila.txt',
#  'jun-28_cairo.txt',
#  'jun-05_dhaka.txt',
#  'may-02_dhaka.txt',
#  'jul-16_manila.txt',
#  'jan-20_cairo.txt',
#  'feb-02_singapore.txt',
#  'jan-04_jakarta.txt',
#  'nov-06_dhaka.txt',
#  'mar-23_jakarta.txt',
#  'mar-09_tokyo.txt',
#  'aug-02_jakarta.txt',
#  'oct-05_shanghai.txt',
#  'apr-21_shanghai.txt',
#  'jun-15_melbourne.txt',
#  'aug-20_cairo.txt',
#  'sep-05_cairo.txt',
#  'feb-15_singapore.txt',
#  'nov-15_tokyo.txt',
#  'may-17_jakarta.txt',
#  'oct-02_osaka.txt',
#  'apr-22_cairo.txt',
#  'aug-22_osaka.txt',
#  'sep-07_osaka.txt',
#  'jul-13_tokyo.txt',
#  'nov-17_singapore.txt',
#  'dec-27_jakarta.txt',
#  'mar-08_manila.txt',
#  'oct-02_shanghai.txt',
#  'jun-27_manila.txt',
#  'dec-27_karachi.txt',
#  'may-05_tokyo.txt',
#  'sep-13_osaka.txt',
#  'jun-10_manila.txt',
#  'may-04_melbourne.txt',
#  'oct-16_osaka.txt',
#  'may-17_karachi.txt',
#  'dec-06_tokyo.txt',
#  'dec-23_singapore.txt',
#  'nov-01_tokyo.txt',
#  'aug-19_dhaka.txt',
#  'jul-09_shanghai.txt',
#  'sep-11_cairo.txt',
#  'jul-23_melbourne.txt',
#  'feb-03_osaka.txt',
#  'feb-23_shanghai.txt',
#  'jan-02_manila.txt',
#  'aug-02_karachi.txt',
#  'dec-09_jakarta.txt',
#  'jan-04_karachi.txt',
#  'dec-23_manila.txt',
#  'jun-11_dhaka.txt',
#  'may-13_melbourne.txt',
#  'apr-24_melbourne.txt',
#  'sep-22_karachi.txt',
#  'nov-13_singapore.txt',
#  'may-25_jakarta.txt',
#  'feb-20_cairo.txt',
#  'oct-18_dhaka.txt',
#  'apr-17_cairo.txt',
#  'aug-17_osaka.txt',
#  'jun-23_tokyo.txt',
#  'jul-26_tokyo.txt',
#  'apr-19_melbourne.txt',
#  'jan-18_karachi.txt',
#  'jul-09_melbourne.txt',
#  'dec-25_shanghai.txt',
#  'dec-15_jakarta.txt',
#  'oct-21_singapore.txt',
#  'jun-06_melbourne.txt',
#  'oct-12_jakarta.txt',
#  'dec-19_cairo.txt',
#  'jan-15_cairo.txt',
#  'jan-27_melbourne.txt',
#  'jul-23_jakarta.txt',
#  'mar-11_jakarta.txt',
#  'apr-29_tokyo.txt',
#  'nov-04_singapore.txt',
#  'dec-22_shanghai.txt',
#  'jun-24_dhaka.txt',
#  'jun-28_melbourne.txt',
#  'jul-23_karachi.txt',
#  'nov-27_dhaka.txt',
#  'dec-20_dhaka.txt',
#  'jan-09_melbourne.txt',
#  'jun-12_karachi.txt',
#  'jul-30_melbourne.txt',
#  'sep-10_karachi.txt',
#  'sep-24_cairo.txt',
#  'aug-01_cairo.txt',
#  'may-27_manila.txt',
#  'jul-27_melbourne.txt',
#  'oct-18_singapore.txt',
#  'may-10_manila.txt',
#  'sep-26_osaka.txt',
#  'may-30_tokyo.txt',
#  'aug-03_osaka.txt',
#  'dec-28_shanghai.txt',
#  'jun-11_karachi.txt',
#  'apr-04_melbourne.txt',
#  'may-08_jakarta.txt',
#  'aug-26_dhaka.txt',
#  'dec-07_cairo.txt',
#  'jun-12_shanghai.txt',
#  'may-26_karachi.txt',
#  'jul-03_melbourne.txt',
#  'jan-19_manila.txt',
#  'sep-10_tokyo.txt',
#  'may-29_dhaka.txt',
#  'apr-13_melbourne.txt',
#  'may-24_melbourne.txt',
#  'apr-23_tokyo.txt',
#  'dec-16_jakarta.txt',
#  'feb-14_tokyo.txt',
#  'oct-19_manila.txt',
#  'oct-01_tokyo.txt',
#  'nov-16_osaka.txt',
#  'sep-04_tokyo.txt',
#  'jun-15_osaka.txt',
#  'oct-12_singapore.txt',
#  'dec-13_cairo.txt',
#  'nov-14_cairo.txt',
#  'feb-02_jakarta.txt',
#  'oct-05_singapore.txt',
#  'feb-07_manila.txt',
#  'mar-13_manila.txt',
#  'jun-29_tokyo.txt',
#  'nov-20_singapore.txt',
#  'oct-12_dhaka.txt',
#  'jul-11_shanghai.txt',
#  'sep-13_jakarta.txt',
#  'mar-24_manila.txt',
#  'oct-08_shanghai.txt',
#  'oct-20_tokyo.txt',
#  'jul-07_melbourne.txt',
#  'jun-07_shanghai.txt',
#  'jun-20_manila.txt',
#  'nov-18_dhaka.txt',
#  'dec-07_singapore.txt',
#  'jun-17_manila.txt',
#  'sep-05_shanghai.txt',
#  'feb-09_osaka.txt',
#  'sep-21_karachi.txt',
#  'jun-08_melbourne.txt',
#  'jul-12_karachi.txt',
#  'feb-08_singapore.txt',
#  'jan-29_melbourne.txt',
#  'jun-08_tokyo.txt',
#  'sep-19_osaka.txt',
#  'aug-26_shanghai.txt',
#  'nov-09_karachi.txt',
#  'aug-28_osaka.txt',
#  'may-19_melbourne.txt',
#  'nov-24_singapore.txt',
#  'jul-19_tokyo.txt',
#  'oct-27_dhaka.txt',
#  'mar-20_jakarta.txt',
#  'oct-05_manila.txt',
#  'jul-12_jakarta.txt',
#  'oct-01_singapore.txt',
#  'oct-23_jakarta.txt',
#  'sep-21_jakarta.txt',
#  'dec-26_cairo.txt',
#  'nov-21_cairo.txt',
#  'jul-03_shanghai.txt',
#  'dec-29_singapore.txt',
#  'aug-14_tokyo.txt',
#  'sep-11_singapore.txt',
#  'apr-07_manila.txt',
#  'oct-16_singapore.txt',
#  'nov-23_osaka.txt',
#  'jul-27_cairo.txt',
#  'may-25_cairo.txt',
#  'feb-21_tokyo.txt',
#  'sep-23_cairo.txt',
#  'jul-18_singapore.txt',
#  'jan-12_jakarta.txt',
#  'sep-21_osaka.txt',
#  'nov-02_melbourne.txt',
#  'aug-26_manila.txt',
#  'apr-23_jakarta.txt',
#  'aug-11_manila.txt',
#  'mar-29_manila.txt',
#  'apr-21_manila.txt',
#  'may-28_singapore.txt',
#  'oct-14_manila.txt',
#  'may-24_dhaka.txt',
#  'jun-23_dhaka.txt',
#  'aug-17_shanghai.txt',
#  'nov-20_dhaka.txt',
#  'oct-30_melbourne.txt',
#  'may-01_jakarta.txt',
#  'dec-27_dhaka.txt',
#  'jun-18_karachi.txt',
#  'sep-19_melbourne.txt',
#  'nov-19_cairo.txt',
#  'jan-23_manila.txt',
#  'jan-12_cairo.txt',
#  'jan-14_manila.txt',
#  'may-30_dhaka.txt',
#  'feb-19_tokyo.txt',
#  'may-06_singapore.txt',
#  'apr-26_singapore.txt',
#  'apr-10_cairo.txt',
#  'feb-18_shanghai.txt',
#  'may-23_tokyo.txt',
#  'aug-10_osaka.txt',
#  'nov-17_manila.txt',
#  'jan-12_karachi.txt',
#  'dec-20_tokyo.txt',
#  'aug-14_karachi.txt',
#  'apr-12_osaka.txt',
#  'mar-05_cairo.txt',
#  'nov-20_manila.txt',
#  'aug-12_cairo.txt',
#  'dec-03_jakarta.txt',
#  'feb-21_manila.txt',
#  'feb-13_melbourne.txt',
#  'sep-26_shanghai.txt',
#  'apr-08_shanghai.txt',
#  'aug-02_shanghai.txt',
#  'nov-15_dhaka.txt',
#  'mar-02_manila.txt',
#  'dec-19_shanghai.txt',
#  'jul-13_dhaka.txt',
#  'may-11_dhaka.txt',
#  'sep-28_karachi.txt',
#  'aug-26_jakarta.txt',
#  'jun-05_tokyo.txt',
#  'may-02_tokyo.txt',
#  'sep-14_osaka.txt',
#  'aug-05_shanghai.txt',
#  'sep-21_shanghai.txt',
#  'oct-08_manila.txt',
#  'sep-24_melbourne.txt',
#  'jun-04_jakarta.txt',
#  'mar-24_cairo.txt',
#  'sep-16_cairo.txt',
#  'oct-04_jakarta.txt',
#  'feb-04_osaka.txt',
#  'jan-19_tokyo.txt',
#  'sep-06_karachi.txt',
#  'feb-10_osaka.txt',
#  'sep-02_cairo.txt',
#  'nov-12_tokyo.txt',
#  'apr-22_singapore.txt',
#  'aug-25_osaka.txt',
#  'jun-11_tokyo.txt',
#  'jan-20_karachi.txt',
#  'jan-08_manila.txt',
#  'may-16_tokyo.txt',
#  'aug-27_melbourne.txt',
#  'aug-26_karachi.txt',
#  'nov-28_melbourne.txt',
#  'jan-25_osaka.txt',
#  'feb-17_karachi.txt',
#  'jun-02_dhaka.txt',
#  'may-05_dhaka.txt',
#  'jul-25_singapore.txt',
#  'dec-06_dhaka.txt',
#  'jan-27_cairo.txt',
#  'nov-01_dhaka.txt',
#  'dec-30_manila.txt',
#  'jan-17_karachi.txt',
#  'aug-11_karachi.txt',
#  'sep-03_shanghai.txt',
#  'nov-19_jakarta.txt',
#  'aug-19_melbourne.txt',
#  'apr-26_karachi.txt',
#  'nov-16_melbourne.txt',
#  'feb-20_dhaka.txt',
#  'jan-11_manila.txt',
#  'jan-26_manila.txt',
#  'jul-18_dhaka.txt',
#  'jun-06_shanghai.txt',
#  'oct-26_tokyo.txt',
#  'sep-04_shanghai.txt',
#  'jan-15_dhaka.txt',
#  'oct-09_shanghai.txt',
#  'dec-19_dhaka.txt',
#  'jun-03_manila.txt',
#  'mar-05_tokyo.txt',
#  'aug-12_tokyo.txt',
#  'apr-24_manila.txt',
#  'apr-13_manila.txt',
#  'feb-20_jakarta.txt',
#  'jul-02_shanghai.txt',
#  'apr-25_singapore.txt',
#  'feb-27_tokyo.txt',
#  'apr-10_tokyo.txt',
#  'may-12_singapore.txt',
#  'dec-22_osaka.txt',
#  'jun-09_dhaka.txt',
#  'nov-25_osaka.txt',
#  'oct-21_dhaka.txt',
#  'apr-26_jakarta.txt',
#  'oct-11_manila.txt',
#  'aug-11_jakarta.txt',
#  'jul-22_singapore.txt',
#  'jul-05_shanghai.txt',
#  'jan-12_tokyo.txt',
#  'mar-30_jakarta.txt',
#  'mar-16_dhaka.txt',
#  'sep-16_tokyo.txt',
#  'jun-07_singapore.txt',
#  'dec-01_cairo.txt',
#  'sep-11_shanghai.txt',
#  'nov-05_melbourne.txt',
#  'feb-06_tokyo.txt',
#  'may-02_cairo.txt',
#  'nov-04_osaka.txt',
#  'jun-28_dhaka.txt',
#  'jun-13_shanghai.txt',
#  'oct-13_tokyo.txt',
#  'jan-25_karachi.txt',
#  'sep-28_cairo.txt',
#  'jul-08_singapore.txt',
#  'aug-20_dhaka.txt',
#  'oct-19_melbourne.txt',
#  'may-18_karachi.txt',
#  'jul-30_jakarta.txt',
#  'aug-19_cairo.txt',
#  'jul-26_singapore.txt',
#  'jul-10_shanghai.txt',
#  'sep-03_jakarta.txt',
#  'feb-13_manila.txt',
#  'dec-28_karachi.txt',
#  'feb-01_dhaka.txt',
#  'may-01_singapore.txt',
#  'may-28_tokyo.txt',
#  'feb-24_manila.txt',
#  'oct-14_dhaka.txt',
#  'may-16_singapore.txt',
#  'jul-19_manila.txt',
#  'aug-24_melbourne.txt',
#  'jul-17_shanghai.txt',
#  'apr-21_singapore.txt',
#  'jul-14_cairo.txt',
#  'feb-12_tokyo.txt',
#  'jul-16_osaka.txt',
#  'sep-09_melbourne.txt',
#  'sep-02_tokyo.txt',
#  'jan-19_cairo.txt',
#  'jul-06_tokyo.txt',
#  'may-27_melbourne.txt',
#  'apr-10_melbourne.txt',
#  'oct-14_jakarta.txt',
#  'sep-16_jakarta.txt',
#  'feb-02_osaka.txt',
#  'jan-30_jakarta.txt',
#  'jul-08_manila.txt',
#  'aug-18_dhaka.txt',
#  'sep-20_shanghai.txt',
#  'aug-04_shanghai.txt',
#  'mar-17_jakarta.txt',
#  'dec-17_singapore.txt',
#  'apr-29_manila.txt',
#  'aug-19_manila.txt',
#  'jul-17_melbourne.txt',
#  'mar-16_manila.txt',
#  'mar-05_singapore.txt',
#  'apr-07_melbourne.txt',
#  'mar-14_shanghai.txt',
#  'may-30_melbourne.txt',
#  'dec-18_shanghai.txt',
#  'may-17_dhaka.txt',
#  'jul-15_dhaka.txt',
#  'sep-27_shanghai.txt',
#  'jul-01_dhaka.txt',
#  'apr-29_melbourne.txt',
#  'jun-04_dhaka.txt',
#  'dec-13_karachi.txt',
#  'jan-22_shanghai.txt',
#  'oct-06_singapore.txt',
#  'jan-21_cairo.txt',
#  'may-23_karachi.txt',
#  'nov-07_dhaka.txt',
#  'jan-30_karachi.txt',
#  'sep-29_dhaka.txt',
#  'jul-26_shanghai.txt',
#  'apr-21_osaka.txt',
#  'feb-16_osaka.txt',
#  'oct-11_singapore.txt',
#  'sep-04_cairo.txt',
#  'may-09_melbourne.txt',
#  'jul-25_karachi.txt',
#  'apr-23_cairo.txt',
#  'sep-06_osaka.txt',
#  'jun-17_tokyo.txt',
#  'jul-12_tokyo.txt',
#  'aug-06_singapore.txt',
#  'jun-25_dhaka.txt',
#  'aug-16_shanghai.txt',
#  'dec-21_dhaka.txt',
#  'oct-26_jakarta.txt',
#  'sep-25_cairo.txt',
#  'sep-24_jakarta.txt',
#  'apr-14_melbourne.txt',
#  'aug-02_osaka.txt',
#  'may-23_melbourne.txt',
#  'apr-02_cairo.txt',
#  'mar-25_jakarta.txt',
#  'aug-05_manila.txt',
#  'jun-12_manila.txt',
#  'jan-02_karachi.txt',
#  'jun-22_tokyo.txt',
#  'jul-27_tokyo.txt',
#  'aug-04_karachi.txt',
#  'jun-25_manila.txt',
#  'apr-14_osaka.txt',
#  'sep-12_singapore.txt',
#  'aug-14_cairo.txt',
#  'jan-13_melbourne.txt',
#  'nov-22_karachi.txt',
#  'dec-18_cairo.txt',
#  'apr-28_tokyo.txt',
#  'nov-27_singapore.txt',
#  'oct-08_jakarta.txt',
#  'jul-19_cairo.txt',
#  'jun-08_jakarta.txt',
#  'aug-25_melbourne.txt',
#  'oct-24_dhaka.txt',
#  'feb-27_manila.txt',
#  'feb-10_manila.txt',
#  'apr-06_jakarta.txt',
#  'sep-11_jakarta.txt',
#  'oct-13_jakarta.txt',
#  'jul-24_cairo.txt',
#  'jul-27_singapore.txt',
#  'feb-22_tokyo.txt',
#  'apr-15_tokyo.txt',
#  'jan-03_shanghai.txt',
#  'jan-19_karachi.txt',
#  'jul-09_dhaka.txt',
#  'jun-23_osaka.txt',
#  'apr-28_jakarta.txt',
#  'apr-19_singapore.txt',
#  'sep-26_tokyo.txt',
#  'mar-14_tokyo.txt',
#  'jul-09_singapore.txt',
#  'jun-18_dhaka.txt',
#  'jan-19_jakarta.txt',
#  'dec-18_manila.txt',
#  'jul-30_cairo.txt',
#  'jun-11_singapore.txt',
#  'apr-06_karachi.txt',
#  'sep-26_melbourne.txt',
#  'jun-06_singapore.txt',
#  'oct-30_dhaka.txt',
#  'aug-10_dhaka.txt',
#  'nov-08_tokyo.txt',
#  'jun-03_shanghai.txt',
#  'aug-25_shanghai.txt',
#  'nov-04_melbourne.txt',
#  'sep-18_cairo.txt',
#  'dec-10_cairo.txt',
#  'dec-26_jakarta.txt',
#  'apr-10_manila.txt',
#  'mar-18_manila.txt',
#  'nov-17_cairo.txt',
#  'may-04_singapore.txt',
#  'jul-13_osaka.txt',
#  'jun-16_osaka.txt',
#  'sep-07_tokyo.txt',
#  'aug-17_manila.txt',
#  'dec-12_osaka.txt',
#  'may-16_jakarta.txt',
#  'jul-23_singapore.txt',
#  'jul-15_shanghai.txt',
#  'apr-20_tokyo.txt',
#  'feb-04_dhaka.txt',
#  'oct-11_dhaka.txt',
#  'may-13_singapore.txt',
#  'jul-06_manila.txt',
#  'oct-25_manila.txt',
#  'jul-12_shanghai.txt',
#  'jun-21_jakarta.txt',
#  'jan-22_tokyo.txt',
#  'aug-08_cairo.txt',
#  'aug-25_dhaka.txt',
#  'oct-05_dhaka.txt',
#  'jan-25_manila.txt',
#  'jun-02_singapore.txt',
#  'oct-19_shanghai.txt',
#  'feb-03_tokyo.txt',
#  'jun-15_singapore.txt',
#  'jul-28_dhaka.txt',
#  'dec-06_osaka.txt',
#  'jun-11_shanghai.txt',
#  'jan-08_cairo.txt',
#  'dec-29_dhaka.txt',
#  'sep-13_tokyo.txt',
#  'jul-07_osaka.txt',
#  'dec-26_karachi.txt',
#  'nov-03_cairo.txt',
#  'nov-17_melbourne.txt',
#  'nov-25_karachi.txt',
#  'dec-04_cairo.txt',
#  'feb-09_jakarta.txt',
#  'jun-26_manila.txt',
#  'oct-29_dhaka.txt',
#  'may-15_tokyo.txt',
#  'sep-03_osaka.txt',
#  'jun-12_tokyo.txt',
#  'feb-24_singapore.txt',
#  'jan-05_melbourne.txt',
#  'jan-10_karachi.txt',
#  'aug-09_dhaka.txt',
#  'jul-24_shanghai.txt',
#  'nov-26_singapore.txt',
#  'aug-24_cairo.txt',
#  'sep-18_jakarta.txt',
#  'sep-09_manila.txt',
#  'may-03_karachi.txt',
#  'nov-02_dhaka.txt',
#  'jul-23_shanghai.txt',
#  'jan-12_melbourne.txt',
#  'sep-13_singapore.txt',
#  'apr-18_tokyo.txt',
#  'jul-29_cairo.txt',
#  'mar-16_shanghai.txt',
#  'jul-20_manila.txt',
#  'dec-05_singapore.txt',
#  'aug-01_shanghai.txt',
#  'sep-25_shanghai.txt',
#  'jul-10_dhaka.txt',
#  'may-03_jakarta.txt',
#  'nov-16_dhaka.txt',
#  'may-22_melbourne.txt',
#  'dec-11_dhaka.txt',
#  'jan-30_cairo.txt',
#  'apr-15_melbourne.txt',
#  'feb-27_jakarta.txt',
#  'feb-07_osaka.txt',
#  'nov-08_singapore.txt',
#  'jan-10_jakarta.txt',
#  'nov-05_tokyo.txt',
#  'may-01_tokyo.txt',
#  'mar-09_manila.txt',
#  'apr-21_jakarta.txt',
#  'jun-28_jakarta.txt',
#  'oct-10_singapore.txt',
#  'jan-16_melbourne.txt',
#  'jan-11_cairo.txt',
#  'dec-30_dhaka.txt',
#  'may-08_melbourne.txt',
#  'feb-26_osaka.txt',
#  'may-26_manila.txt',
#  'sep-04_karachi.txt',
#  'mar-06_cairo.txt',
#  'nov-24_tokyo.txt',
#  'may-11_manila.txt',
#  'sep-19_dhaka.txt',
#  'may-28_shanghai.txt',
#  'jan-22_karachi.txt',
#  'apr-13_cairo.txt',
#  'aug-13_osaka.txt',
#  'feb-20_singapore.txt',
#  'mar-04_osaka.txt',
#  'oct-07_singapore.txt',
#  'jul-16_melbourne.txt',
#  'sep-22_osaka.txt',
#  'mar-10_osaka.txt',
#  'apr-07_cairo.txt',
#  'oct-29_singapore.txt',
#  'dec-08_shanghai.txt',
#  'apr-19_shanghai.txt',
#  'aug-13_shanghai.txt',
#  'oct-28_manila.txt',
#  'aug-05_cairo.txt',
#  'mar-12_cairo.txt',
#  'sep-20_cairo.txt',
#  'oct-06_jakarta.txt',
#  'apr-13_jakarta.txt',
#  'apr-11_melbourne.txt',
#  'dec-09_cairo.txt',
#  'feb-01_manila.txt',
#  'may-26_melbourne.txt',
#  'mar-22_manila.txt',
#  'dec-24_dhaka.txt',
#  'jan-05_cairo.txt',
#  'jun-20_dhaka.txt',
#  'aug-14_shanghai.txt',
#  'may-27_dhaka.txt',
#  'jul-01_melbourne.txt',
#  'jul-08_cairo.txt',
#  'oct-28_karachi.txt',
#  'feb-15_jakarta.txt',
#  'feb-19_singapore.txt',
#  'dec-28_singapore.txt',
#  'may-28_karachi.txt',
#  'jul-29_tokyo.txt',
#  'jan-10_shanghai.txt',
#  'jan-11_melbourne.txt',
#  'apr-24_jakarta.txt',
#  'aug-13_jakarta.txt',
#  'jan-24_tokyo.txt',
#  'oct-06_manila.txt',
#  'jul-25_manila.txt',
#  'sep-01_tokyo.txt',
#  'nov-25_singapore.txt',
#  'jul-15_osaka.txt',
#  'apr-04_manila.txt',
#  'feb-18_manila.txt',
#  'aug-03_manila.txt',
#  'jul-17_cairo.txt',
#  'jan-06_melbourne.txt',
#  'feb-27_singapore.txt',
#  'jan-18_osaka.txt',
#  'dec-14_osaka.txt',
#  'sep-07_singapore.txt',
#  'nov-05_manila.txt',
#  'feb-05_tokyo.txt',
#  'sep-29_singapore.txt',
#  'may-01_cairo.txt',
#  'nov-05_cairo.txt',
#  'may-06_karachi.txt',
#  'jun-10_shanghai.txt',
#  'apr-01_melbourne.txt',
#  'mar-27_tokyo.txt',
#  'jun-04_osaka.txt',
#  'nov-28_dhaka.txt',
#  'aug-23_dhaka.txt',
#  'apr-16_melbourne.txt',
#  'oct-18_shanghai.txt',
#  'may-21_melbourne.txt',
#  'mar-19_cairo.txt',
#  'dec-18_jakarta.txt',
#  'dec-06_singapore.txt',
#  'sep-15_shanghai.txt',
#  'may-28_jakarta.txt',
#  'jul-06_melbourne.txt',
#  'sep-29_osaka.txt',
#  'dec-21_osaka.txt',
#  'sep-03_singapore.txt',
#  'oct-04_singapore.txt',
#  'may-18_shanghai.txt',
#  'feb-10_jakarta.txt',
#  'feb-23_singapore.txt',
#  'feb-24_tokyo.txt',
#  'dec-23_cairo.txt',
#  'dec-04_jakarta.txt',
#  'jan-09_karachi.txt',
#  'aug-02_dhaka.txt',
#  'oct-03_jakarta.txt',
#  'apr-16_jakarta.txt',
#  'jun-03_jakarta.txt',
#  'nov-29_karachi.txt',
#  'aug-21_jakarta.txt',
#  'jul-06_shanghai.txt',
#  'sep-08_osaka.txt',
#  'mar-10_manila.txt',
#  'feb-04_manila.txt',
#  'aug-28_manila.txt',
#  'oct-13_singapore.txt',
#  'jul-02_melbourne.txt',
#  'dec-02_singapore.txt',
#  'aug-21_karachi.txt',
#  'oct-03_karachi.txt',
#  'apr-16_karachi.txt',
#  'apr-12_melbourne.txt',
#  'dec-09_tokyo.txt',
#  'apr-05_melbourne.txt',
#  'aug-05_tokyo.txt',
#  'sep-20_tokyo.txt',
#  'sep-07_shanghai.txt',
#  'apr-29_shanghai.txt',
#  'apr-07_tokyo.txt',
#  'oct-25_tokyo.txt',
#  'nov-22_tokyo.txt',
#  'dec-25_tokyo.txt',
#  'feb-20_osaka.txt',
#  'may-05_manila.txt',
#  'sep-01_manila.txt',
#  'jun-16_karachi.txt',
#  'apr-15_cairo.txt',
#  'feb-22_cairo.txt',
#  'aug-15_osaka.txt',
#  'nov-08_manila.txt',
#  'jan-15_osaka.txt',
#  'nov-29_melbourne.txt',
#  'apr-23_singapore.txt',
#  'jul-09_jakarta.txt',
#  'aug-08_melbourne.txt',
#  'aug-15_shanghai.txt',
#  'feb-15_manila.txt',
#  'jul-09_karachi.txt',
#  'jan-03_cairo.txt',
#  'feb-22_manila.txt',
#  'dec-11_jakarta.txt',
#  'jan-01_osaka.txt',
#  'jul-23_dhaka.txt',
#  'may-21_dhaka.txt',
#  'jun-05_singapore.txt',
#  'jun-26_dhaka.txt',
#  'sep-24_osaka.txt',
#  'aug-12_shanghai.txt',
#  'apr-18_shanghai.txt',
#  'jul-27_jakarta.txt',
#  'oct-23_cairo.txt',
#  'oct-16_jakarta.txt',
#  'sep-26_cairo.txt',
#  'mar-14_cairo.txt',
#  'aug-03_cairo.txt',
#  'apr-03_osaka.txt',
#  'nov-10_melbourne.txt',
#  'mar-15_jakarta.txt',
#  'jul-28_manila.txt',
#  'dec-03_dhaka.txt',
#  'mar-09_jakarta.txt',
#  'jul-22_shanghai.txt',
#  'nov-04_dhaka.txt',
#  'jun-28_osaka.txt',
#  'aug-22_melbourne.txt',
#  'aug-28_jakarta.txt',
#  'nov-29_cairo.txt',
#  'jan-20_osaka.txt',
#  'jun-07_dhaka.txt',
#  'jul-02_dhaka.txt',
#  'apr-20_cairo.txt',
#  'feb-17_cairo.txt',
#  'jul-11_tokyo.txt',
#  'aug-20_osaka.txt',
#  'jun-14_tokyo.txt',
#  'jun-05_manila.txt',
#  'jan-26_shanghai.txt',
#  'sep-26_karachi.txt',
#  'sep-07_cairo.txt',
#  'nov-17_tokyo.txt',
#  'nov-14_manila.txt',
#  'dec-10_tokyo.txt',
#  'nov-03_tokyo.txt',
#  'sep-13_cairo.txt',
#  'jan-08_tokyo.txt',
#  'feb-01_osaka.txt',
#  'oct-24_jakarta.txt',
#  'apr-19_dhaka.txt',
#  'aug-12_manila.txt',
#  'feb-16_melbourne.txt',
#  'apr-22_manila.txt',
#  'feb-09_manila.txt',
#  'sep-11_osaka.txt',
#  'sep-23_shanghai.txt',
#  'aug-25_manila.txt',
#  'jul-05_tokyo.txt',
#  'jun-16_singapore.txt',
#  'sep-21_melbourne.txt',
#  'may-13_jakarta.txt',
#  'jul-16_dhaka.txt',
#  'jun-01_singapore.txt',
#  'may-14_dhaka.txt',
#  'jul-03_manila.txt',
#  'oct-20_manila.txt',
#  'dec-23_jakarta.txt',
#  'nov-20_jakarta.txt',
#  'nov-03_melbourne.txt',
#  'dec-17_dhaka.txt',
#  'aug-15_manila.txt',
#  'apr-25_manila.txt',
#  'mar-15_tokyo.txt',
#  'jan-03_jakarta.txt',
#  'aug-05_jakarta.txt',
#  ...]

# %%
os.getcwd()
# Out:
# '/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/os-collaboration-exercise-data'

# %%
kill_me = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(eat):
    for old_file_name in eat:
        ugh = str(old_file_name).split('-')
        dying=ugh[0] 
        try: 
            os.rename(old_file_name, kill_me[dying]+"-"+ugh[1])
        except:
            print("please work") 

rename_my_file(os.listdir('/Users/keeganlee-ng/Documents/GitHub/learning-portfolio-KeeganLeeNg/files, folders and os/os-collaboration-exercise-data'))
# Out:
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work
# please work

# %%
os.listdir()
# Out:
# ['01-02_manila.txt',
#  '12-03_cairo.txt',
#  '06-23_singapore.txt',
#  '08-29_shanghai.txt',
#  '09-06_melbourne.txt',
#  '07-04_singapore.txt',
#  '09-29_osaka.txt',
#  '04-27_shanghai.txt',
#  '09-11_melbourne.txt',
#  '11-03_melbourne.txt',
#  '01-30_cairo.txt',
#  '09-27_jakarta.txt',
#  '02-24_singapore.txt',
#  '10-07_shanghai.txt',
#  '09-01_tokyo.txt',
#  '09-15_shanghai.txt',
#  '09-28_melbourne.txt',
#  '02-19_tokyo.txt',
#  '12-15_osaka.txt',
#  '06-09_dhaka.txt',
#  '08-14_dhaka.txt',
#  '02-07_manila.txt',
#  '11-14_cairo.txt',
#  '04-21_cairo.txt',
#  '04-15_singapore.txt',
#  '05-27_cairo.txt',
#  '12-17_cairo.txt',
#  '11-16_osaka.txt',
#  '04-23_osaka.txt',
#  '09-20_tokyo.txt',
#  '02-04_osaka.txt',
#  '02-20_singapore.txt',
#  '05-06_karachi.txt',
#  '01-05_cairo.txt',
#  '09-15_melbourne.txt',
#  '07-17_singapore.txt',
#  '09-15_jakarta.txt',
#  '06-28_dhaka.txt',
#  '11-18_dhaka.txt',
#  '10-15_shanghai.txt',
#  '02-21_jakarta.txt',
#  '05-28_jakarta.txt',
#  '09-02_melbourne.txt',
#  '08-18_cairo.txt',
#  '08-25_melbourne.txt',
#  '11-10_melbourne.txt',
#  '04-16_osaka.txt',
#  '11-23_osaka.txt',
#  '06-09_singapore.txt',
#  '10-04_manila.txt',
#  '05-12_cairo.txt',
#  '12-22_cairo.txt',
#  '02-19_singapore.txt',
#  '07-17_cairo.txt',
#  '12-11_shanghai.txt',
#  '04-14_cairo.txt',
#  '01-22_melbourne.txt',
#  '01-14_karachi.txt',
#  '12-18_shanghai.txt',
#  '12-05_singapore.txt',
#  '04-15_melbourne.txt',
#  '01-25_manila.txt',
#  '11-02_tokyo.txt',
#  '02-22_dhaka.txt',
#  '04-23_tokyo.txt',
#  '07-03_shanghai.txt',
#  '03-25_jakarta.txt',
#  '07-08_manila.txt',
#  '07-20_tokyo.txt',
#  '02-19_osaka.txt',
#  '12-06_dhaka.txt',
#  '10-24_singapore.txt',
#  '07-04_jakarta.txt',
#  '12-04_jakarta.txt',
#  '09-11_singapore.txt',
#  '10-08_manila.txt',
#  '08-11_jakarta.txt',
#  '04-02_karachi.txt',
#  '11-03_singapore.txt',
#  '08-05_cairo.txt',
#  '09-01_osaka.txt',
#  '09-26_karachi.txt',
#  '02-10_manila.txt',
#  '08-22_dhaka.txt',
#  '07-16_osaka.txt',
#  '12-23_osaka.txt',
#  '04-17_cairo.txt',
#  '02-27_manila.txt',
#  '07-14_cairo.txt',
#  '12-21_cairo.txt',
#  ...]

# %%
countries = ['Cairo','Dhaka','Jakarta','Karachi','Manila','Melbourne', 'Osaka', 'Shanghai', 'Osaka', 'Shanghai','Singapore', 'Tokyo']
for i in countries: 
    os.mkdir(i) #reviewed, this should work right?
# Out:
#   File "/var/folders/y3/jh2xk8816tj_l6xs6gt2q4k40000gn/T/ipykernel_4800/653653516.py", line 16
#     glob.glob(os-collaboration-exercise-data/**/*{i}, recursive=True):
#                                              ^
# SyntaxError: invalid syntax

# %%
os.mkdir('Cairo')
os.mkdir('Dhaka')
os.mkdir('Jakarta')
os.mkdir('Karachi')
os.mkdir('Manila')
os.mkdir('Melbourne')
os.mkdir('Osaka')
os.mkdir('Shanghai')
os.mkdir('Singapore')
os.mkdir('Tokyo')

# %%
files  = [i for i in os.listdir() if '_cairo' in i]
for file in files:
    new_path = 'Cairo/' + file 
    shutil.move(file, new_path)

# %%
files  = [i for i in os.listdir() if '_dhaka' in i]
for file in files:
    new_path = 'Dhaka/' + file 
    shutil.move(file, new_path)
    
files  = [i for i in os.listdir() if '_jakarta' in i]
for file in files:
    new_path = 'Jakarta/' + file 
    shutil.move(file, new_path)

files  = [i for i in os.listdir() if '_karachi' in i]
for file in files:
    new_path = 'Karachi/' + file 
    shutil.move(file, new_path)

files  = [i for i in os.listdir() if '_manila' in i]
for file in files:
    new_path = 'Manila/' + file 
    shutil.move(file, new_path) 
    
files  = [i for i in os.listdir() if '_melbourne' in i]
for file in files:
    new_path = 'Melbourne/' + file 
    shutil.move(file, new_path) 
    
files  = [i for i in os.listdir() if '_osaka' in i]
for file in files:
    new_path = 'Osaka/' + file 
    shutil.move(file, new_path) 
    
files  = [i for i in os.listdir() if '_shanghai' in i]
for file in files:
    new_path = 'Shanghai/' + file 
    shutil.move(file, new_path) 
    
files  = [i for i in os.listdir() if '_singapore' in i]
for file in files:
    new_path = 'Singapore/' + file 
    shutil.move(file, new_path) 
    
files  = [i for i in os.listdir() if '_tokyo' in i]
for file in files:
    new_path = 'Tokyo/' + file 
    shutil.move(file, new_path)
